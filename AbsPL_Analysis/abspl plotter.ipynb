# %% [markdown]
# # AbsPL Analyzer (Modular)
#
# This notebook now launches the modular AbsPL app with:
# - PL vs sweep auto-detection
# - Select Upload, Select Filters, Select Plots, and Diagnostics tabs
# - Resizable Plotly figures with SVG and high-DPI PNG export
#
# Legacy cells are kept below for reference.

# %%
# Modular AbsPL launcher (new architecture)
import os
import sys

cwd = os.getcwd()
candidate_dirs = [
    cwd,
    os.path.join(cwd, "AbsPL_Analysis"),
]
for path in candidate_dirs:
    if os.path.isdir(path) and path not in sys.path:
        sys.path.append(path)

from app_controller_abspl import launch_abspl_app

abspl_app = launch_abspl_app(url_base="http://elnserver.lti.kit.edu")
