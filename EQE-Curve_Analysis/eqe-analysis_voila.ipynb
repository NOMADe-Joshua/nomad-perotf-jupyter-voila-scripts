# %%
# Imports and app bootstrap
import os
import sys
import plotly.io as pio
from plotly.offline import init_notebook_mode
from IPython.display import display, HTML

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
if current_dir not in sys.path:
    sys.path.append(current_dir)

init_notebook_mode(connected=True)
pio.renderers.default = 'notebook'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
# Launch EQE dashboard
from app_controller_EQE import EQEAnalysisApp

display(HTML("<script>document.title='NOMAD EQE Analyzer'</script>"))
app = EQEAnalysisApp()
display(app.get_dashboard())
print('EQE dashboard launched.')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Launch EQE dashboard
# ----> 2 from app_controller_EQE import EQEAnalysisApp
#       4 display(HTML("<script>document.title='NOMAD EQE Analyzer'</script>"))
#       5 app = EQEAnalysisApp()
#
# File c:\nomad-perotf-jupyter-voila-scripts\EQE-Curve_Analysis\app_controller_EQE.py:26
#      23 if jv_dir not in sys.path:
#      24     sys.path.append(jv_dir)
# ---> 26 from batch_selection import create_batch_selection
#      27 from data_manager_EQE import DataManagerEQE
#      28 from plot_manager_EQE import create_eqe_figure
#
# File c:\nomad-perotf-jupyter-voila-scripts\batch_selection.py:2
#       1 import ipywidgets as widgets
# ----> 2 from api_calls import get_batch_ids
#       3 import re
#       5 def extract_date(s):
#       6     # Suche nach jedem 8-stelligen Datum, das mit "20" beginnt
#
# ...
