# %% [markdown]
# # XRD Analysis Dashboard
#
# Interactive application for loading XRD diffractograms from the NOMAD API,
# overlaying patterns, detecting peaks, and fitting Gaussian profiles.

# %%
from app_controller_XRD import XRDAnalysisApp
from IPython.display import display

app = XRDAnalysisApp()
display(app.get_dashboard())
# Out:
# ✅ ipyvuetify FileInput initialized
# no stored variable or alias h5_path
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# ...
